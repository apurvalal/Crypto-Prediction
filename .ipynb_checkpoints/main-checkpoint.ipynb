# %%
import numpy as np
import pandas as pd
import keras

import os
# Out:
# 2021-11-16 15:22:23.944847: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-16 15:22:23.944870: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import matplotlib.pyplot as plt

data = 'archive/coin_Bitcoin.csv'
dataset = pd.read_csv(data)
chosen_col = 'Close'

# %%
print(len(dataset))
dataset.head()
# Out:
# 2991
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
split_row = len(dataset) - int(0.2 * len(dataset))
train_data = dataset.iloc[:split_row]
test_data = dataset.iloc[split_row:]

# %%
fig, ax = plt.subplots(1, figsize=(13, 7))
ax.plot(train_data[chosen_col], label='Train', linewidth=2)
ax.plot(test_data[chosen_col], label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

# %%
from sklearn.preprocessing import MinMaxScaler

datacol = dataset.iloc[:, 7:8].values
traincol = train_data.iloc[:, 7:8].values
testcol = test_data.iloc[:, 7:8].values

shaped_data = np.reshape(datacol, (-1,1))
train_shaped = np.reshape(traincol, (-1,1))
test_shaped = np.reshape(testcol, (-1,1))

sc = MinMaxScaler(feature_range=(0,1))
sc.fit(shaped_data)

train_scaled_data = sc.transform(train_shaped)
test_scaled_data = sc.transform(test_shaped)

# %%
X = []
y = []
time_steps = 50

for i in range(time_steps, len(train_data)):
    X.append(train_scaled_data[i-time_steps:i,0])
    y.append(train_scaled_data[i, 0])

X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation

model = Sequential()
model.add(LSTM(units=100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('linear'))
model.compile(optimizer='adam', loss='mse')
# Out:
# 2021-11-15 19:06:58.076801: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-11-15 19:06:58.076835: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pop-os): /proc/driver/nvidia/version does not exist
# 2021-11-15 19:06:58.077265: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
len(train_data)
# Out:
# 2393

# %%
from keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1, callbacks=[callback], shuffle=True)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 3s 27ms/step - loss: 3.8136e-04 - val_loss: 5.5181e-05
# Epoch 2/100
# 59/59 [==============================] - 1s 22ms/step - loss: 9.0408e-05 - val_loss: 4.5562e-05
# Epoch 3/100
# 59/59 [==============================] - 1s 21ms/step - loss: 9.2552e-05 - val_loss: 6.3279e-05
# Epoch 4/100
# 59/59 [==============================] - 1s 21ms/step - loss: 8.2667e-05 - val_loss: 3.9720e-05
# Epoch 5/100
# 59/59 [==============================] - 1s 21ms/step - loss: 7.3813e-05 - val_loss: 5.1812e-05
# Epoch 6/100
# 59/59 [==============================] - 1s 21ms/step - loss: 6.9714e-05 - val_loss: 3.6233e-05
# Epoch 7/100
# 59/59 [==============================] - 1s 21ms/step - loss: 7.7319e-05 - val_loss: 3.4799e-05
# Epoch 8/100
# 59/59 [==============================] - 1s 21ms/step - loss: 6.4216e-05 - val_loss: 4.7426e-05
# Epoch 9/100
# 59/59 [==============================] - 1s 21ms/step - loss: 6.6529e-05 - val_loss: 3.6721e-05
# Epoch 10/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.9202e-05 - val_loss: 3.0677e-05
# Epoch 11/100
# 59/59 [==============================] - 1s 21ms/step - loss: 6.0961e-05 - val_loss: 2.7718e-05
# Epoch 12/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.5540e-05 - val_loss: 2.9609e-05
# Epoch 13/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.9260e-05 - val_loss: 2.5560e-05
# Epoch 14/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.6517e-05 - val_loss: 2.7649e-05
# Epoch 15/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.7033e-05 - val_loss: 2.9857e-05
# Epoch 16/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.0587e-05 - val_loss: 2.6849e-05
# Epoch 17/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.9120e-05 - val_loss: 2.7739e-05
# Epoch 18/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.5497e-05 - val_loss: 2.4871e-05
# Epoch 19/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.6928e-05 - val_loss: 3.9648e-05
# Epoch 20/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.1810e-05 - val_loss: 2.3797e-05
# Epoch 21/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.6204e-05 - val_loss: 3.7867e-05
# Epoch 22/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.7968e-05 - val_loss: 2.3843e-05
# Epoch 23/100
# 59/59 [==============================] - 1s 21ms/step - loss: 5.3039e-05 - val_loss: 2.2438e-05
# Epoch 24/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1366e-05 - val_loss: 2.4920e-05
# Epoch 25/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.8332e-05 - val_loss: 2.4652e-05
# Epoch 26/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.5500e-05 - val_loss: 2.3782e-05
# Epoch 27/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.5364e-05 - val_loss: 2.3298e-05
# Epoch 28/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.7753e-05 - val_loss: 2.0788e-05
# Epoch 29/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.8190e-05 - val_loss: 2.2001e-05
# Epoch 30/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.3079e-05 - val_loss: 2.1613e-05
# Epoch 31/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.5070e-05 - val_loss: 1.9990e-05
# Epoch 32/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1548e-05 - val_loss: 3.6861e-05
# Epoch 33/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.6338e-05 - val_loss: 4.0049e-05
# Epoch 34/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.3448e-05 - val_loss: 1.9836e-05
# Epoch 35/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.5017e-05 - val_loss: 1.9052e-05
# Epoch 36/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.7771e-05 - val_loss: 1.8818e-05
# Epoch 37/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.7838e-05 - val_loss: 2.5370e-05
# Epoch 38/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1980e-05 - val_loss: 2.1580e-05
# Epoch 39/100
# 59/59 [==============================] - 1s 23ms/step - loss: 4.0945e-05 - val_loss: 1.9230e-05
# Epoch 40/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1393e-05 - val_loss: 2.4773e-05
# Epoch 41/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.6192e-05 - val_loss: 2.2414e-05
# Epoch 42/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.5983e-05 - val_loss: 2.1236e-05
# Epoch 43/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.2196e-05 - val_loss: 1.9240e-05
# Epoch 44/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.4862e-05 - val_loss: 2.1259e-05
# Epoch 45/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.6841e-05 - val_loss: 1.8213e-05
# Epoch 46/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.9942e-05 - val_loss: 2.5547e-05
# Epoch 47/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1249e-05 - val_loss: 2.0520e-05
# Epoch 48/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.8518e-05 - val_loss: 2.3888e-05
# Epoch 49/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.6348e-05 - val_loss: 2.2006e-05
# Epoch 50/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.8628e-05 - val_loss: 1.9785e-05
# Epoch 51/100
# 59/59 [==============================] - 1s 21ms/step - loss: 4.1987e-05 - val_loss: 1.7835e-05
# Epoch 52/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.8825e-05 - val_loss: 1.8018e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import r2_score, max_error, mean_squared_error
y_pred1 = model.predict(X_test)
y_pred = np.argmax(y_pred1, axis=1)

print(mean_squared_error(y_test, y_pred1))
print(max_error(y_test, y_pred1))
print(r2_score(y_test, y_pred1))
# Out:
# 2.1235875063017384e-05
# 0.025878246915828018
# 0.9938309181805439

# %%
from keras.metrics import mean_absolute_error

X_testing = []
y_testing = []

for i in range(time_steps, len(test_data)):
    X_testing.append(test_scaled_data[i-time_steps:i,0])
    y_testing.append(test_scaled_data[i, 0])

X_testing, y_testing = np.array(X_testing), np.array(y_testing)
X_testing = np.reshape(X_testing, (X_testing.shape[0], X_testing.shape[1], 1))

predicted_price = model.predict(X_testing)
inv_price = sc.inverse_transform(predicted_price)
real_price = np.reshape(y_testing, (-1,1))
real_price = sc.inverse_transform(real_price)

# %%
y_testing
# Out:
# array([0.12139647, 0.127615  , 0.1262935 , 0.1231282 , 0.12766012,
#        0.12562628, 0.12806904, 0.12730764, 0.13808355, 0.13775637,
#        0.13644441, 0.13968003, 0.13989713, 0.1361679 , 0.13540172,
#        0.13679294, 0.13576797, 0.13144292, 0.13205643, 0.13083335,
#        0.13444306, 0.13937707, 0.14645157, 0.14579009, 0.14882255,
#        0.1463245 , 0.14699205, 0.14622732, 0.14542581, 0.14365142,
#        0.15046881, 0.15230341, 0.15334608, 0.15443658, 0.15840212,
#        0.15430246, 0.15984553, 0.16170283, 0.15994237, 0.1614831 ,
#        0.15481973, 0.15552925, 0.15167821, 0.15880131, 0.15078351,
#        0.15039081, 0.15161986, 0.1512532 , 0.1553729 , 0.15104816,
#        0.14618539, 0.13796938, 0.13740142, 0.13563523, 0.13448528,
#        0.13390115, 0.13874416, 0.13745333, 0.13694035, 0.14204032,
#        0.14273052, 0.13937919, 0.1267389 , 0.12383086, 0.12361149,
#        0.1236383 , 0.07728155, 0.08662842, 0.08090066, 0.08392656,
#        0.07797031, 0.0812989 , 0.08150083, 0.09652021, 0.09663978,
#        0.09642363, 0.09083032, 0.10006906, 0.10508978, 0.1042426 ,
#        0.1048003 , 0.10091218, 0.09732419, 0.09227729, 0.10028231,
#        0.10042108, 0.10307153, 0.10601704, 0.10506745, 0.10718205,
#        0.1059777 , 0.11355477, 0.1120514 , 0.11453715, 0.11403256,
#        0.10714999, 0.10704893, 0.10881466, 0.10682752, 0.10678638,
#        0.10362853, 0.11111169, 0.11078664, 0.11333224, 0.1122565 ,
#        0.10740955, 0.10738377, 0.11111805, 0.11604462, 0.11795486,
#        0.11825494, 0.11998791, 0.12181235, 0.12199297, 0.13766222,
#        0.13541609, 0.13866686, 0.14061892, 0.13918237, 0.13942177,
#        0.14084709, 0.1450355 , 0.15579859, 0.15408262, 0.15016098,
#        0.13695904, 0.13452135, 0.13771645, 0.14505482, 0.1523652 ,
#        0.14597245, 0.146742  , 0.15137234, 0.15225254, 0.15229137,
#        0.14904305, 0.1420876 , 0.14367688, 0.14409794, 0.13749402,
#        0.1393316 , 0.13819844, 0.14365229, 0.14908672, 0.14772112,
#        0.15184014, 0.1480669 , 0.1591997 , 0.14915061, 0.1511513 ,
#        0.15342006, 0.15129026, 0.1511034 , 0.15276137, 0.15296058,
#        0.15334224, 0.154515  , 0.14587131, 0.14837879, 0.14829104,
#        0.14689608, 0.14790363, 0.1492802 , 0.14836952, 0.14729101,
#        0.14533907, 0.14603777, 0.14558516, 0.15102518, 0.15072473,
#        0.1457425 , 0.14497325, 0.14336695, 0.14151425, 0.14306215,
#        0.14380736, 0.14297405, 0.14439806, 0.14274415, 0.14217497,
#        0.14288726, 0.14196434, 0.14671774, 0.14477564, 0.14755101,
#        0.14518063, 0.14519387, 0.14458755, 0.14515748, 0.14463906,
#        0.14463275, 0.14383861, 0.14288316, 0.14318527, 0.14330583,
#        0.14372794, 0.14338766, 0.14670848, 0.14908061, 0.14995881,
#        0.78248414, 0.74131634, 0.7294287 , 0.72704344, 0.71048034,
#        0.78131614, 0.76157542, 0.79561427, 0.7644473 , 0.77021917,
#        0.76998392, 0.80615181, 0.82254385, 0.86317748, 0.88184905,
#        0.91017053, 0.90271354, 0.96436711, 0.93377254, 0.88025137,
#        0.89440287, 0.9269715 , 0.9110186 , 0.91870729, 0.91818691,
#        0.90572973, 0.85852749, 0.8618348 , 0.83086325, 0.81399399,
#        0.86811475, 0.8812967 , 0.88093783, 0.90930471, 0.92770926,
#        0.92772723, 0.93051709, 0.93506514, 0.90699825, 0.9252006 ,
#        0.92991918, 0.91627497, 0.88248574, 0.91834946, 0.91710487,
#        0.94151145, 0.94800202, 0.94309128, 1.        , 0.99379267,
#        0.99701353, 0.96956463, 0.95555079, 0.88512225, 0.87736758,
#        0.88917124, 0.84870551, 0.81491005, 0.8043698 , 0.78793121,
#        0.7714322 , 0.8505289 , 0.86647219, 0.86318674, 0.84317261,
#        0.90930436, 0.91053196, 0.89166268, 0.90063586, 0.83967974,
#        0.90416254, 0.88796499, 0.90309682, 0.92591345, 0.91690487,
#        0.8795041 , 0.89282128, 0.77373819, 0.78265531, 0.78524602,
#        0.73605637, 0.73126204, 0.6852536 , 0.67535196, 0.58223368,
#        0.64182691, 0.58699841, 0.59065475, 0.54705033, 0.60908854,
#        0.6043001 , 0.61836131, 0.60484782, 0.56166407, 0.54461452,
#        0.56135703, 0.58744237, 0.57722831, 0.59126244, 0.61701456,
#        0.5805306 , 0.55936806, 0.56426155, 0.52797766, 0.52658921,
#        0.58763576, 0.57750694, 0.58746674, 0.55937686, 0.61526623,
#        0.63293182, 0.63589219, 0.60343053, 0.59880282, 0.56307714,
#        0.56037555, 0.56167495, 0.49827775, 0.51134571, 0.53053651,
#        0.54534548, 0.49766431, 0.50631092, 0.54514383, 0.54174966,
#        0.56434668, 0.55131066, 0.52815752, 0.53327979, 0.54544183,
#        0.5552035 , 0.53089867, 0.53861036])

# %%
X_train
# Out:
# array([[[0.09694752],
#         [0.09987493],
#         [0.09958834],
#         ...,
#         [0.09836977],
#         [0.09878295],
#         [0.10265936]],
#
#        [[0.00554582],
#         [0.00538868],
#         [0.00495091],
#         ...,
#         [0.00545267],
#         [0.00544716],
#         [0.00546116]],
#
#        [[0.1517942 ],
#         [0.13836692],
#         [0.14523646],
#         ...,
#         [0.10589716],
#         [0.10780304],
#         [0.10268663]],
#
#        ...,
#
#        [[0.00582197],
#         [0.00555379],
#         [0.0056203 ],
#         ...,
#         [0.00553291],
#         [0.00556685],
#         [0.00558133]],
#
#        [[0.0552944 ],
#         [0.05574438],
#         [0.0554377 ],
#         ...,
#         [0.06139956],
#         [0.0612149 ],
#         [0.06048388]],
#
#        [[0.00847694],
#         [0.00845427],
#         [0.00846948],
#         ...,
#         [0.00998817],
#         [0.01003531],
#         [0.01013932]]])

# %%
fig, ax = plt.subplots(1, figsize=(13, 7))
ax.plot(real_price, label='Real', linewidth=2)
ax.plot(inv_price, label='Pred', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)
